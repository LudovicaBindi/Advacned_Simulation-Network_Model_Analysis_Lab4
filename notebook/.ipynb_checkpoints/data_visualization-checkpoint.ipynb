# %% [markdown]
# **imports**

# %%
import os
import pandas as pd                    
import seaborn as sns                  
import matplotlib.pyplot as plt
import time

start_time = time.time()

# %%
# General settings

directory = '../experiment/' # directory of the csv files (output of the model)

# formatting data types and visualisations
pd.options.display.float_format = "{:,.2f}".format
sns.set(rc={'figure.figsize':(10,10)})
sns.set(font_scale=1.5,style="white")

# scenarios and replications settings
n_scenarios = 4 # variable to help iterate through the files
n_replications = 10 # variable to help iterate through the files

# %% [markdown]
# ### Baseline scenario ###

# %% [markdown]
# This part of the analysis focus on analysing the average travel time and wait time for the baseline scenario. This scenario is a benchmark, in which no bridges break

# %%
appended_data_baseline = pd.DataFrame(columns = ['Truck id','Travel time','Total waiting time','Created at','Removed at','Path','Scenario','Replication'])


for replication_id in range(n_replications):
    
    
    # iterating through the files (travel times)
    file_travel_times = 'scenario_0'+'_replication_'+str(replication_id)+'_travel_time.csv'
    
    
    # creating dataframes for each output csv (travel time)
    travel_time_model_output = pd.read_csv(os.path.join(directory,file_travel_times),index_col=[0])
    travel_time_model_output["Path"] = travel_time_model_output[['Created at', 'Removed at']].agg('-'.join, axis=1) # adding Path column
    travel_time_model_output["Scenario"] = 0 # adding Scenario column
    travel_time_model_output["Replication"] = replication_id # adding Replication column
    
    
    appended_data_baseline = appended_data_baseline.append(travel_time_model_output,ignore_index = True)
    appended_data_baseline[['Travel time', 'Total waiting time','Scenario','Replication']] = appended_data_baseline[['Travel time', 'Total waiting time','Scenario','Replication']].apply(pd.to_numeric)
    appended_data_baseline = appended_data_baseline.sort_values(["Scenario","Replication"],ascending=True)

# %%
# checking the dataset shape (rows,columns)
appended_data_baseline.shape
# Out:
# (222097, 8)

# %%
# checking the dataset structure
appended_data_baseline.head()
# Out:
#   Truck id  Travel time  Total waiting time Created at Removed at  \
# 0   Truck0           16                   0    N1_LRPS  N105_LRPS
# 1  Truck40           16                   0  N105_LRPS    N1_LRPS
# 2  Truck10           44                   0  N204_LRPS  N204_LRPE
# 3  Truck11           44                   0  N204_LRPE  N204_LRPS
# 4  Truck15           47                   0  N208_LRPE  N207_LRPE
#
#                   Path  Scenario  Replication
# 0    N1_LRPS-N105_LRPS         0            0
# 1    N105_LRPS-N1_LRPS         0            0
# 2  N204_LRPS-N204_LRPE         0            0
# 3  N204_LRPE-N204_LRPS         0            0
# 4  N208_LRPE-N207_LRPE         0            0

# %%
# checking the dataset data types
appended_data_baseline.dtypes
# Out:
# Truck id              object
# Travel time            int64
# Total waiting time     int64
# Created at            object
# Removed at            object
# Path                  object
# Scenario               int64
# Replication            int64
# dtype: object

# %%
# checking how many unique paths the dataset has
unique_paths = list(appended_data_baseline.Path.unique())
print("Number of unique paths in baseline scenario: " + str(len(unique_paths)))
# Out:
# Number of unique paths in baseline scenario: 240

# %% [markdown]
# Computing the relevant indicators (average travel time and wait time) for baseline scenario

# %%
col_names_scenarios = ['Scenario','Replication','Mean travel time', 'Mean wait time']
col_names_paths = ['Scenario','Path','Mean travel time', 'Mean wait time']

for elem in range(n_scenarios):

    # computing mean travel time considering the scenario granularity and the path granularity
    mean_travel_time_scenario = appended_data_baseline.groupby(['Scenario','Replication'], as_index=False)['Travel time'].mean()
    mean_travel_time_path = appended_data_baseline.groupby(['Scenario','Path'], as_index=False)['Travel time'].mean()
    
    
    # computing mean wait time considering the scenario granularity and the path granularity
    mean_wait_time_scenario = appended_data_baseline.groupby(['Scenario','Replication'], as_index=False)['Total waiting time'].mean()
    mean_wait_time_path = appended_data_baseline.groupby(['Scenario','Path'], as_index=False)['Total waiting time'].mean()
    
    # merging dataframes
    scenario_level_KPIs_baseline = pd.merge(mean_travel_time_scenario,mean_wait_time_scenario)
    scenario_level_KPIs_baseline.set_index("Scenario")
    scenario_level_KPIs_baseline = scenario_level_KPIs_baseline.set_axis(col_names_scenarios, axis=1)

    path_level_KPIs_baseline = pd.merge(mean_travel_time_path,mean_wait_time_path)
    path_level_KPIs_baseline.set_index("Scenario")
    path_level_KPIs_baseline = path_level_KPIs_baseline.set_axis(col_names_paths, axis=1)

# %% [markdown]
# Visualizing the results for the baseline scenario

# %%
# Plotting the KPIs for the baseline scenario

parameters = {'axes.labelsize': 16,
          'axes.titlesize': 16,
          'xtick.labelsize': 12,
          'ytick.labelsize': 12}
plt.rcParams.update(parameters)

indicators = {}
indicators["long_names"] = {}
indicators["long_names"]["Mean travel time"] = "Average throughput time (travel time)"
indicators["long_names"]["Mean wait time"] = "Average waiting time"


cols_interest = ['Mean travel time', 'Mean wait time']

# Create figure and axes
f, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))
f.tight_layout(pad = 5)
# Make the axes accessible with single indexing
axs = axs.flatten()
# Start the loop over all the variables of interest
for i, col in enumerate(cols_interest):
    # select the axis
    ax = axs[i]
    # Plot the boxplot
    sns.boxplot(x="Replication", y=col, palette = "Spectral", data=scenario_level_KPIs_baseline, ax = ax,showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"6"})
    


    ax.set_title(indicators["long_names"][col])
 
# Display the figure
plt.show()

# %%
# getting the average values for each scenario (depicted as blue circles on each boxplot above)
# since we only have 1 value for each replication, these values represent both the median and the mean on the charts above

baseline_values_Mean_travel_time = scenario_level_KPIs_baseline.groupby(['Replication'], as_index=False)['Mean travel time'].mean()
baseline_values_Mean_wait_time = scenario_level_KPIs_baseline.groupby(['Replication'], as_index=False)['Mean wait time'].mean()
baseline_values = pd.merge(baseline_values_Mean_travel_time,baseline_values_Mean_wait_time)
baseline_values["Mean travel time (in hours)"] = baseline_values["Mean travel time"] / 60
baseline_values["Mean wait time (in hours)"] = baseline_values["Mean wait time"] / 60
baseline_values
# Out:
#    Replication  Mean travel time  Mean wait time  Mean travel time (in hours)  \
# 0            0            252.06            0.00                         4.20
# 1            1            253.51            0.00                         4.23
# 2            2            252.65            0.00                         4.21
# 3            3            253.35            0.00                         4.22
# 4            4            253.06            0.00                         4.22
# 5            5            251.95            0.00                         4.20
# 6            6            252.94            0.00                         4.22
# 7            7            252.51            0.00                         4.21
# 8            8            253.42            0.00                         4.22
# 9            9            255.85            0.00                         4.26
#
#    Mean wait time (in hours)
# 0                       0.00
# 1                       0.00
# ...

# %% [markdown]
# ### Scenarios 1 to 4 ###

# %% [markdown]
# Going through the output files of the scenarios and replications

# %%
appended_data_scenarios = pd.DataFrame(columns = ['Truck id','Travel time','Total waiting time','Created at','Removed at','Path','Scenario','Replication'])

for scenario_id in range(n_scenarios):
    for replication_id in range(n_replications):
        
        
        # iterating through the files (travel times)
        file_travel_times = 'scenario_'+str(scenario_id+1)+'_replication_'+str(replication_id)+'_travel_time.csv'
        
        
        # creating dataframes for each output csv (travel time)
        travel_time_model_output = pd.read_csv(os.path.join(directory,file_travel_times),index_col=[0])
        travel_time_model_output["Path"] = travel_time_model_output[['Created at', 'Removed at']].agg('-'.join, axis=1) # adding Path column
        travel_time_model_output["Scenario"] = scenario_id+1 # adding Scenario column
        travel_time_model_output["Replication"] = replication_id # adding Replication column

        
        appended_data_scenarios = appended_data_scenarios.append(travel_time_model_output,ignore_index = True)
        appended_data_scenarios[['Travel time', 'Total waiting time','Scenario','Replication']] = appended_data_scenarios[['Travel time', 'Total waiting time','Scenario','Replication']].apply(pd.to_numeric)
        appended_data_scenarios = appended_data_scenarios.sort_values(["Scenario","Replication"],ascending=True)

# %%
# checking the dataset shape (rows,columns)
appended_data_scenarios.shape
# Out:
# (875902, 8)

# %%
# checking the dataset structure
appended_data_scenarios.head()
# Out:
#       Truck id  Travel time  Total waiting time Created at Removed at  \
# 0  Truck230400           11                0.00    N1_LRPS    N2_LRPS
# 1  Truck230472            5                0.00  N105_LRPS    N2_LRPS
# 2  Truck230482            5                0.00    N2_LRPS  N105_LRPS
# 3  Truck230415           47                0.00  N208_LRPE  N207_LRPE
# 4  Truck230426           44                0.00  N204_LRPS  N204_LRPE
#
#                   Path  Scenario  Replication
# 0      N1_LRPS-N2_LRPS         1            0
# 1    N105_LRPS-N2_LRPS         1            0
# 2    N2_LRPS-N105_LRPS         1            0
# 3  N208_LRPE-N207_LRPE         1            0
# 4  N204_LRPS-N204_LRPE         1            0

# %%
# checking the dataset data types 
appended_data_scenarios.dtypes
# Out:
# Truck id               object
# Travel time             int64
# Total waiting time    float64
# Created at             object
# Removed at             object
# Path                   object
# Scenario                int64
# Replication             int64
# dtype: object

# %%
# checking how many unique paths the dataset has
unique_paths = list(appended_data_scenarios.Path.unique())
print("Number of unique paths in all scenarios: " + str(len(unique_paths)))
# Out:
# Number of unique paths in all scenarios: 240

# %% [markdown]
# Computing the relevant indicators (average travel time and wait time) for each scenario

# %%
col_names_scenarios = ['Scenario','Replication','Mean travel time', 'Mean wait time']
col_names_paths = ['Scenario','Path','Mean travel time', 'Mean wait time']

for elem in range(n_scenarios):

    # computing mean travel time considering the scenario granularity and the path granularity
    mean_travel_time_scenario = appended_data_scenarios.groupby(['Scenario','Replication'], as_index=False)['Travel time'].mean()
    mean_travel_time_path = appended_data_scenarios.groupby(['Scenario','Path'], as_index=False)['Travel time'].mean()
    
    # computing mean wait time considering the scenario granularity and the path granularity
    mean_wait_time_scenario = appended_data_scenarios.groupby(['Scenario','Replication'], as_index=False)['Total waiting time'].mean()
    mean_wait_time_path = appended_data_scenarios.groupby(['Scenario','Path'], as_index=False)['Total waiting time'].mean()
    
    # merging dataframes
    scenario_level_KPIs = pd.merge(mean_travel_time_scenario,mean_wait_time_scenario)
    scenario_level_KPIs.set_index("Scenario")
    scenario_level_KPIs = scenario_level_KPIs.set_axis(col_names_scenarios, axis=1)

    path_level_KPIs = pd.merge(mean_travel_time_path,mean_wait_time_path)
    path_level_KPIs.set_index("Scenario")
    path_level_KPIs = path_level_KPIs.set_axis(col_names_paths, axis=1)

# %% [markdown]
# Visualizing the results based on the different scenarios

# %%
# Plotting the KPIs

parameters = {'axes.labelsize': 16,
          'axes.titlesize': 16,
          'xtick.labelsize': 16,
          'ytick.labelsize': 16}
plt.rcParams.update(parameters)

indicators = {}
indicators["long_names"] = {}
indicators["long_names"]["Mean travel time"] = "Average throughput time (travel time)"
indicators["long_names"]["Mean wait time"] = "Average waiting time"


cols_interest = ['Mean travel time', 'Mean wait time']

# Create figure and axes
f, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))
f.tight_layout(pad = 5)
# Make the axes accessible with single indexing
axs = axs.flatten()
# Start the loop over all the variables of interest
for i, col in enumerate(cols_interest):
    # select the axis
    ax = axs[i]
    # Plot the boxplot
    sns.boxplot(x="Scenario", y=col, palette = "rocket_r", data=scenario_level_KPIs, ax = ax,showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"6"}) 
    ax.set_title(indicators["long_names"][col])
    ax.set_ylabel(col + ' (in minutes)')
    

# Display the figure
plt.show()

# %%
# getting the average values for each scenario (depicted as blue circles on each boxplot above) and also the share of travel time as waiting time

scenario_level_values_Mean_travel_time = scenario_level_KPIs.groupby(['Scenario'], as_index=False)['Mean travel time'].mean()
scenario_level_values_Mean_wait_time = scenario_level_KPIs.groupby(['Scenario'], as_index=False)['Mean wait time'].mean()
scenario_level_values = pd.merge(scenario_level_values_Mean_travel_time,scenario_level_values_Mean_wait_time)
scenario_level_values["Mean travel time (in hours)"] = scenario_level_values["Mean travel time"] / 60
scenario_level_values["Mean wait time (in hours)"] = scenario_level_values["Mean wait time"] / 60
scenario_level_values["Share of travel time as waiting time"] = scenario_level_values["Mean wait time"] / scenario_level_values["Mean travel time"]

scenario_level_values
# Out:
#    Scenario  Mean travel time  Mean wait time  Mean travel time (in hours)  \
# 0         1            254.10            0.52                         4.24
# 1         2            270.89           19.33                         4.51
# 2         3            310.95           61.97                         5.18
# 3         4            520.41          284.92                         8.67
#
#    Mean wait time (in hours)  Share of travel time as waiting time
# 0                       0.01                                  0.00
# 1                       0.32                                  0.07
# 2                       1.03                                  0.20
# 3                       4.75                                  0.55

# %% [markdown]
# Visualizing the results based on the different paths each truck can travel

# %% [markdown]
# Mean travel time per path

# %%
path_level_KPIs = path_level_KPIs.sort_values("Mean travel time",ascending=True)

# formatting visualisations

sns.set_theme(style="ticks")
parameters = {'axes.labelsize': 16,
          'axes.titlesize': 16,
          'xtick.labelsize': 16,
          'ytick.labelsize': 12}
plt.rcParams.update(parameters)

cols_interest = ['Mean travel time', 'Mean wait time']

# Initialize the figure
f, ax = plt.subplots(figsize=(16, 70))


# Plot box plot
sns.boxplot(x="Mean travel time", y="Path", data=path_level_KPIs, whis=[0, 100], width=.6, palette="Spectral",showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"4"})


# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="Path of truck")
ax.set_xlabel("Mean travel time (in minutes)")
ax.set_title("Distribution of average travel time per path",fontdict={'fontsize': 16, 'fontweight': 'medium'})
sns.despine(trim=True, left=True)
#plt.savefig("box_travel_time.svg",format="svg")

# %% [markdown]
# Mean wait time per path

# %%
path_level_KPIs = path_level_KPIs.sort_values("Mean wait time",ascending=True)

# formatting visualisations

sns.set_theme(style="ticks")
parameters = {'axes.labelsize': 16,
          'axes.titlesize': 16,
          'xtick.labelsize': 12,
          'ytick.labelsize': 12}
plt.rcParams.update(parameters)

cols_interest = ['Mean travel time', 'Mean wait time']

# Initialize the figure
f, ax = plt.subplots(figsize=(16, 70))


# Plot box plot
sns.boxplot(x="Mean wait time", y="Path", data=path_level_KPIs, whis=[0, 100], width=.6, palette="Spectral",showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                       "markersize":"4"})


# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="Path of truck")
ax.set_xlabel("Mean wait time (in minutes)")
ax.set_title("Distribution of average wait time per path",fontdict={'fontsize': 16, 'fontweight': 'medium'})
sns.despine(trim=True, left=True)
#plt.savefig("box_wait_time.svg",format="svg")

# %%
print("Process finished --- %s seconds ---" % (time.time() - start_time))
# Out:
# Process finished --- 101.10511827468872 seconds ---
